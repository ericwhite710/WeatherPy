# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import timeit
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
         cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 767

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | tlahualilo
# City not found. Skipping...
# Processing Record 3 of Set 1 | dongsheng
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 1 | kodiak
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 1 | faanui
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | san pedro
# Processing Record 13 of Set 1 | saint-pierre
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | iqaluit
# Processing Record 16 of Set 1 | hami
# Processing Record 17 of Set 1 | beyneu
# Processing Record 18 of Set 1 | pontes e lacerda
# Processing Record 19 of Set 1 | los llanos de aridane
# Processing Record 20 of Set 1 | airai
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | alekseyevsk
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | deputatskiy
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | krasnoselkup
# Processing Record 30 of Set 1 | urusha
# Processing Record 31 of Set 1 | provideniya
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | carepa
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | mahebourg
# Processing Record 39 of Set 1 | victoria
# Processing Record 40 of Set 1 | port lincoln
# Processing Record 41 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 1 | araci
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 1 | hofn
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | aanekoski
# Processing Record 48 of Set 1 | saint-joseph
# Processing Record 49 of Set 1 | yumen
# Processing Record 50 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 1 of Set 2 | sorland
# Processing Record 2 of Set 2 | padang
# Processing Record 3 of Set 2 | ikalamavony
# Processing Record 4 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | odweyne
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | cherskiy
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | linxia
# Processing Record 12 of Set 2 | jurado
# Processing Record 13 of Set 2 | marsa matruh
# Processing Record 14 of Set 2 | sarangani
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | lompoc
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | portland
# Processing Record 20 of Set 2 | nome
# Processing Record 21 of Set 2 | vao
# Processing Record 22 of Set 2 | xining
# Processing Record 23 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 2 | hamilton
# Processing Record 25 of Set 2 | chuy
# Processing Record 26 of Set 2 | narsaq
# Processing Record 27 of Set 2 | geraldton
# Processing Record 28 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 2 | balabac
# Processing Record 30 of Set 2 | katsuura
# Processing Record 31 of Set 2 | tuatapere
# Processing Record 32 of Set 2 | bathsheba
# Processing Record 33 of Set 2 | aklavik
# Processing Record 34 of Set 2 | torbay
# Processing Record 35 of Set 2 | mecca
# Processing Record 36 of Set 2 | kysyl-syr
# Processing Record 37 of Set 2 | assela
# City not found. Skipping...
# Processing Record 38 of Set 2 | kapaa
# Processing Record 39 of Set 2 | oarai
# Processing Record 40 of Set 2 | chebenki
# Processing Record 41 of Set 2 | sambava
# Processing Record 42 of Set 2 | the valley
# Processing Record 43 of Set 2 | viedma
# Processing Record 44 of Set 2 | katiola
# Processing Record 45 of Set 2 | tiarei
# Processing Record 46 of Set 2 | sovetskiy
# Processing Record 47 of Set 2 | praxedis guerrero
# Processing Record 48 of Set 2 | takoradi
# Processing Record 49 of Set 2 | uarini
# Processing Record 50 of Set 2 | macklin
# Processing Record 1 of Set 3 | pacific grove
# Processing Record 2 of Set 3 | esperance
# Processing Record 3 of Set 3 | thermon
# City not found. Skipping...
# Processing Record 4 of Set 3 | horadiz
# Processing Record 5 of Set 3 | zaysan
# Processing Record 6 of Set 3 | guerrero negro
# Processing Record 7 of Set 3 | moerai
# Processing Record 8 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 3 | wageningen
# Processing Record 10 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 3 | hithadhoo
# Processing Record 13 of Set 3 | new norfolk
# Processing Record 14 of Set 3 | karlstad
# Processing Record 15 of Set 3 | samarai
# Processing Record 16 of Set 3 | atambua
# Processing Record 17 of Set 3 | entre rios
# Processing Record 18 of Set 3 | kyren
# Processing Record 19 of Set 3 | anahuac
# Processing Record 20 of Set 3 | kahului
# Processing Record 21 of Set 3 | andenes
# Processing Record 22 of Set 3 | lavrentiya
# Processing Record 23 of Set 3 | butaritari
# Processing Record 24 of Set 3 | north bay
# Processing Record 25 of Set 3 | dikson
# Processing Record 26 of Set 3 | hambantota
# Processing Record 27 of Set 3 | himora
# City not found. Skipping...
# Processing Record 28 of Set 3 | isangel
# Processing Record 29 of Set 3 | vaini
# Processing Record 30 of Set 3 | sibolga
# Processing Record 31 of Set 3 | grindavik
# Processing Record 32 of Set 3 | berlevag
# Processing Record 33 of Set 3 | salinopolis
# Processing Record 34 of Set 3 | jacqueville
# Processing Record 35 of Set 3 | batagay-alyta
# Processing Record 36 of Set 3 | port hardy
# Processing Record 37 of Set 3 | arman
# Processing Record 38 of Set 3 | longyearbyen
# Processing Record 39 of Set 3 | husavik
# Processing Record 40 of Set 3 | necochea
# Processing Record 41 of Set 3 | goderich
# Processing Record 42 of Set 3 | bell ville
# Processing Record 43 of Set 3 | ahuimanu
# Processing Record 44 of Set 3 | vila do maio
# Processing Record 45 of Set 3 | san antonio del tachira
# Processing Record 46 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 3 | lewiston
# Processing Record 48 of Set 3 | flinders
# Processing Record 49 of Set 3 | chokurdakh
# Processing Record 50 of Set 3 | sena madureira
# Processing Record 1 of Set 4 | jiayuguan
# Processing Record 2 of Set 4 | barrow
# Processing Record 3 of Set 4 | karratha
# Processing Record 4 of Set 4 | mikuni
# Processing Record 5 of Set 4 | kitgum
# Processing Record 6 of Set 4 | puerto del rosario
# Processing Record 7 of Set 4 | saldanha
# Processing Record 8 of Set 4 | tiksi
# Processing Record 9 of Set 4 | kavieng
# Processing Record 10 of Set 4 | nabire
# Processing Record 11 of Set 4 | dingle
# Processing Record 12 of Set 4 | herat
# Processing Record 13 of Set 4 | ilulissat
# Processing Record 14 of Set 4 | kampene
# Processing Record 15 of Set 4 | umm kaddadah
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | nikolskoye
# Processing Record 18 of Set 4 | sirjan
# Processing Record 19 of Set 4 | toktogul
# Processing Record 20 of Set 4 | kudahuvadhoo
# Processing Record 21 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 4 | tanshui
# City not found. Skipping...
# Processing Record 23 of Set 4 | salalah
# Processing Record 24 of Set 4 | namibe
# Processing Record 25 of Set 4 | arraial do cabo
# Processing Record 26 of Set 4 | kinablangan
# Processing Record 27 of Set 4 | zhigansk
# Processing Record 28 of Set 4 | talnakh
# Processing Record 29 of Set 4 | norman wells
# Processing Record 30 of Set 4 | bredasdorp
# Processing Record 31 of Set 4 | constitucion
# Processing Record 32 of Set 4 | maningrida
# Processing Record 33 of Set 4 | iquitos
# Processing Record 34 of Set 4 | iracoubo
# Processing Record 35 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 4 | tekkali
# Processing Record 37 of Set 4 | qaanaaq
# Processing Record 38 of Set 4 | creel
# Processing Record 39 of Set 4 | asau
# Processing Record 40 of Set 4 | puerto carreno
# Processing Record 41 of Set 4 | port-cartier
# Processing Record 42 of Set 4 | la rioja
# Processing Record 43 of Set 4 | vila velha
# Processing Record 44 of Set 4 | christchurch
# Processing Record 45 of Set 4 | tiverton
# Processing Record 46 of Set 4 | rayachoti
# Processing Record 47 of Set 4 | kuching
# Processing Record 48 of Set 4 | waingapu
# Processing Record 49 of Set 4 | antequera
# Processing Record 50 of Set 4 | baghdad
# Processing Record 1 of Set 5 | simplicio mendes
# Processing Record 2 of Set 5 | teluk nibung
# Processing Record 3 of Set 5 | tarsus
# Processing Record 4 of Set 5 | kikwit
# Processing Record 5 of Set 5 | kirakira
# Processing Record 6 of Set 5 | upernavik
# Processing Record 7 of Set 5 | bemidji
# Processing Record 8 of Set 5 | willemstad
# Processing Record 9 of Set 5 | erzin
# Processing Record 10 of Set 5 | port moresby
# Processing Record 11 of Set 5 | red bluff
# Processing Record 12 of Set 5 | lazaro cardenas
# Processing Record 13 of Set 5 | mandali
# Processing Record 14 of Set 5 | prescott
# Processing Record 15 of Set 5 | cabo san lucas
# Processing Record 16 of Set 5 | rio grande
# Processing Record 17 of Set 5 | coquimbo
# Processing Record 18 of Set 5 | nizwa
# Processing Record 19 of Set 5 | east london
# Processing Record 20 of Set 5 | ust-tsilma
# Processing Record 21 of Set 5 | sitka
# Processing Record 22 of Set 5 | atar
# Processing Record 23 of Set 5 | serro
# Processing Record 24 of Set 5 | ilo
# Processing Record 25 of Set 5 | cidreira
# Processing Record 26 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 5 | ambon
# Processing Record 28 of Set 5 | san patricio
# Processing Record 29 of Set 5 | rovaniemi
# Processing Record 30 of Set 5 | tres arroyos
# Processing Record 31 of Set 5 | ifanadiana
# Processing Record 32 of Set 5 | lagoa
# Processing Record 33 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 5 | naryan-mar
# Processing Record 35 of Set 5 | buchanan
# Processing Record 36 of Set 5 | kapit
# Processing Record 37 of Set 5 | kruisfontein
# Processing Record 38 of Set 5 | tuktoyaktuk
# Processing Record 39 of Set 5 | trinidad
# Processing Record 40 of Set 5 | marsh harbour
# Processing Record 41 of Set 5 | henderson
# Processing Record 42 of Set 5 | omsukchan
# Processing Record 43 of Set 5 | chapais
# Processing Record 44 of Set 5 | nova olimpia
# Processing Record 45 of Set 5 | impfondo
# Processing Record 46 of Set 5 | le mars
# Processing Record 47 of Set 5 | cap malheureux
# Processing Record 48 of Set 5 | marawi
# Processing Record 49 of Set 5 | sindand
# City not found. Skipping...
# Processing Record 50 of Set 5 | jasper
# Processing Record 1 of Set 6 | souillac
# Processing Record 2 of Set 6 | wahpeton
# Processing Record 3 of Set 6 | krasnyy luch
# Processing Record 4 of Set 6 | sembakung
# Processing Record 5 of Set 6 | porto torres
# Processing Record 6 of Set 6 | westport
# Processing Record 7 of Set 6 | vallenar
# Processing Record 8 of Set 6 | byron bay
# Processing Record 9 of Set 6 | houma
# Processing Record 10 of Set 6 | clyde river
# Processing Record 11 of Set 6 | huari
# Processing Record 12 of Set 6 | quelimane
# Processing Record 13 of Set 6 | tangshan
# Processing Record 14 of Set 6 | tereze
# Processing Record 15 of Set 6 | saskylakh
# Processing Record 16 of Set 6 | olafsvik
# Processing Record 17 of Set 6 | burnie
# Processing Record 18 of Set 6 | ulaangom
# Processing Record 19 of Set 6 | roma
# Processing Record 20 of Set 6 | ballina
# Processing Record 21 of Set 6 | kurilsk
# Processing Record 22 of Set 6 | kon tum
# Processing Record 23 of Set 6 | indramayu
# Processing Record 24 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 25 of Set 6 | thunder bay
# Processing Record 26 of Set 6 | the pas
# Processing Record 27 of Set 6 | naqadeh
# Processing Record 28 of Set 6 | kawalu
# Processing Record 29 of Set 6 | bure
# Processing Record 30 of Set 6 | sobolevo
# Processing Record 31 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 6 | waitati
# Processing Record 33 of Set 6 | san francisco menendez
# Processing Record 34 of Set 6 | la gaulette
# City not found. Skipping...
# Processing Record 35 of Set 6 | moindou
# Processing Record 36 of Set 6 | leshukonskoye
# Processing Record 37 of Set 6 | manicore
# Processing Record 38 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 6 | batsfjord
# Processing Record 40 of Set 6 | iranshahr
# Processing Record 41 of Set 6 | iroquois falls
# Processing Record 42 of Set 6 | alofi
# Processing Record 43 of Set 6 | roanoke
# Processing Record 44 of Set 6 | zurrieq
# Processing Record 45 of Set 6 | vardo
# Processing Record 46 of Set 6 | murashi
# Processing Record 47 of Set 6 | sahrak
# City not found. Skipping...
# Processing Record 48 of Set 6 | la mira
# Processing Record 49 of Set 6 | belaya gora
# Processing Record 50 of Set 6 | codrington
# Processing Record 1 of Set 7 | bereznyky
# Processing Record 2 of Set 7 | kloulklubed
# Processing Record 3 of Set 7 | bathurst
# Processing Record 4 of Set 7 | yurla
# Processing Record 5 of Set 7 | broome
# Processing Record 6 of Set 7 | yafran
# Processing Record 7 of Set 7 | tual
# Processing Record 8 of Set 7 | okhotsk
# Processing Record 9 of Set 7 | kaitangata
# Processing Record 10 of Set 7 | komsomolskiy
# Processing Record 11 of Set 7 | pisco
# Processing Record 12 of Set 7 | point fortin
# Processing Record 13 of Set 7 | varkaus
# Processing Record 14 of Set 7 | tailai
# Processing Record 15 of Set 7 | amalapuram
# Processing Record 16 of Set 7 | esna
# Processing Record 17 of Set 7 | yelyzavethradka
# Processing Record 18 of Set 7 | manaus
# Processing Record 19 of Set 7 | port hedland
# Processing Record 20 of Set 7 | mnogovershinnyy
# Processing Record 21 of Set 7 | porto novo
# Processing Record 22 of Set 7 | dubbo
# Processing Record 23 of Set 7 | malanje
# Processing Record 24 of Set 7 | faya
# Processing Record 25 of Set 7 | ayan
# Processing Record 26 of Set 7 | chigorodo
# Processing Record 27 of Set 7 | cheney
# Processing Record 28 of Set 7 | mokhsogollokh
# Processing Record 29 of Set 7 | rudbar
# Processing Record 30 of Set 7 | pevek
# Processing Record 31 of Set 7 | bichura
# Processing Record 32 of Set 7 | pachperwa
# Processing Record 33 of Set 7 | north bend
# Processing Record 34 of Set 7 | georgetown
# Processing Record 35 of Set 7 | polyarnyy
# Processing Record 36 of Set 7 | myitkyina
# Processing Record 37 of Set 7 | risor
# Processing Record 38 of Set 7 | pozo colorado
# Processing Record 39 of Set 7 | te anau
# Processing Record 40 of Set 7 | hasaki
# Processing Record 41 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 7 | muisne
# Processing Record 43 of Set 7 | carnarvon
# Processing Record 44 of Set 7 | la ronge
# Processing Record 45 of Set 7 | fortuna
# Processing Record 46 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 7 | vanimo
# Processing Record 48 of Set 7 | huarmey
# Processing Record 49 of Set 7 | port macquarie
# Processing Record 50 of Set 7 | iralaya
# Processing Record 1 of Set 8 | egvekinot
# Processing Record 2 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 8 | talavera
# Processing Record 4 of Set 8 | misratah
# Processing Record 5 of Set 8 | llaillay
# Processing Record 6 of Set 8 | luderitz
# Processing Record 7 of Set 8 | kaeo
# Processing Record 8 of Set 8 | kununurra
# Processing Record 9 of Set 8 | havoysund
# Processing Record 10 of Set 8 | buraydah
# Processing Record 11 of Set 8 | shumskiy
# Processing Record 12 of Set 8 | saint george
# Processing Record 13 of Set 8 | binzhou
# Processing Record 14 of Set 8 | walla walla
# Processing Record 15 of Set 8 | aykhal
# Processing Record 16 of Set 8 | thinadhoo
# Processing Record 17 of Set 8 | bilma
# Processing Record 18 of Set 8 | bengkulu
# Processing Record 19 of Set 8 | leander
# Processing Record 20 of Set 8 | acapulco
# Processing Record 21 of Set 8 | lorengau
# Processing Record 22 of Set 8 | ruwi
# Processing Record 23 of Set 8 | mareeba
# Processing Record 24 of Set 8 | port-gentil
# Processing Record 25 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 26 of Set 8 | peniche
# Processing Record 27 of Set 8 | havre
# Processing Record 28 of Set 8 | oil city
# Processing Record 29 of Set 8 | mitsamiouli
# Processing Record 30 of Set 8 | udachnyy
# Processing Record 31 of Set 8 | chillicothe
# Processing Record 32 of Set 8 | howard springs
# Processing Record 33 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 8 | banda aceh
# Processing Record 35 of Set 8 | sembe
# Processing Record 36 of Set 8 | russell
# Processing Record 37 of Set 8 | sinjar
# Processing Record 38 of Set 8 | meybod
# Processing Record 39 of Set 8 | ancud
# Processing Record 40 of Set 8 | tautira
# Processing Record 41 of Set 8 | beringovskiy
# Processing Record 42 of Set 8 | colquiri
# Processing Record 43 of Set 8 | olkhovka
# Processing Record 44 of Set 8 | candelaria
# Processing Record 45 of Set 8 | saint anthony
# Processing Record 46 of Set 8 | tete
# Processing Record 47 of Set 8 | mezen
# Processing Record 48 of Set 8 | smithers
# Processing Record 49 of Set 8 | tirumullaivasal
# Processing Record 50 of Set 8 | severo-kurilsk
# Processing Record 1 of Set 9 | upleta
# Processing Record 2 of Set 9 | mangrol
# Processing Record 3 of Set 9 | kabompo
# Processing Record 4 of Set 9 | la baneza
# Processing Record 5 of Set 9 | verkhnyaya inta
# Processing Record 6 of Set 9 | valparaiso
# Processing Record 7 of Set 9 | kaliganj
# Processing Record 8 of Set 9 | cadiz
# Processing Record 9 of Set 9 | stromness
# Processing Record 10 of Set 9 | san jose
# Processing Record 11 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 12 of Set 9 | ketchikan
# Processing Record 13 of Set 9 | monte alegre
# Processing Record 14 of Set 9 | ust-karsk
# Processing Record 15 of Set 9 | bababe
# City not found. Skipping...
# Processing Record 16 of Set 9 | mount isa
# Processing Record 17 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 9 | fortaleza
# Processing Record 19 of Set 9 | inyonga
# Processing Record 20 of Set 9 | chibombo
# Processing Record 21 of Set 9 | tamalameque
# Processing Record 22 of Set 9 | puerto ayacucho
# Processing Record 23 of Set 9 | griffith
# Processing Record 24 of Set 9 | pathein
# Processing Record 25 of Set 9 | pasighat
# Processing Record 26 of Set 9 | churapcha
# Processing Record 27 of Set 9 | ilhabela
# Processing Record 28 of Set 9 | ambanja
# Processing Record 29 of Set 9 | melissourgoi
# City not found. Skipping...
# Processing Record 30 of Set 9 | caravelas
# Processing Record 31 of Set 9 | ranong
# Processing Record 32 of Set 9 | vestmannaeyjar
# Processing Record 33 of Set 9 | damavand
# Processing Record 34 of Set 9 | kushiro
# Processing Record 35 of Set 9 | agua verde
# Processing Record 36 of Set 9 | almeirim
# Processing Record 37 of Set 9 | vostok
# Processing Record 38 of Set 9 | franklin
# Processing Record 39 of Set 9 | acajutla
# Processing Record 40 of Set 9 | nantucket
# Processing Record 41 of Set 9 | utete
# Processing Record 42 of Set 9 | flin flon
# Processing Record 43 of Set 9 | quatre cocos
# Processing Record 44 of Set 9 | ponta delgada
# Processing Record 45 of Set 9 | rock hill
# Processing Record 46 of Set 9 | catuday
# Processing Record 47 of Set 9 | turukhansk
# Processing Record 48 of Set 9 | roebourne
# Processing Record 49 of Set 9 | klyuchi
# Processing Record 50 of Set 9 | zhirnovsk
# Processing Record 1 of Set 10 | oistins
# Processing Record 2 of Set 10 | oktyabrskoye
# Processing Record 3 of Set 10 | scalloway
# City not found. Skipping...
# Processing Record 4 of Set 10 | bubaque
# Processing Record 5 of Set 10 | shush
# Processing Record 6 of Set 10 | gravdal
# Processing Record 7 of Set 10 | nemuro
# Processing Record 8 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 9 of Set 10 | mehran
# Processing Record 10 of Set 10 | dianopolis
# City not found. Skipping...
# Processing Record 11 of Set 10 | pinega
# Processing Record 12 of Set 10 | ixtapa
# Processing Record 13 of Set 10 | bakchar
# Processing Record 14 of Set 10 | katobu
# Processing Record 15 of Set 10 | sal rei
# Processing Record 16 of Set 10 | bastia
# Processing Record 17 of Set 10 | santa rosalia
# Processing Record 18 of Set 10 | sola
# Processing Record 19 of Set 10 | baymak
# Processing Record 20 of Set 10 | dalvik
# Processing Record 21 of Set 10 | srednekolymsk
# Processing Record 22 of Set 10 | luang prabang
# Processing Record 23 of Set 10 | tomatlan
# Processing Record 24 of Set 10 | rio gallegos
# Processing Record 25 of Set 10 | denton
# Processing Record 26 of Set 10 | leirvik
# Processing Record 27 of Set 10 | alice springs
# Processing Record 28 of Set 10 | ola
# Processing Record 29 of Set 10 | champoton
# Processing Record 30 of Set 10 | alibunan
# Processing Record 31 of Set 10 | chajul
# Processing Record 32 of Set 10 | merauke
# Processing Record 33 of Set 10 | kota bahru
# Processing Record 34 of Set 10 | west wendover
# Processing Record 35 of Set 10 | phu ly
# Processing Record 36 of Set 10 | poum
# Processing Record 37 of Set 10 | rabo de peixe
# Processing Record 38 of Set 10 | gornyy
# Processing Record 39 of Set 10 | moranbah
# Processing Record 40 of Set 10 | moree
# Processing Record 41 of Set 10 | nyurba
# Processing Record 42 of Set 10 | conceicao do araguaia
# Processing Record 43 of Set 10 | nhulunbuy
# Processing Record 44 of Set 10 | roseburg
# Processing Record 45 of Set 10 | yar-sale
# Processing Record 46 of Set 10 | hay river
# Processing Record 47 of Set 10 | port elizabeth
# Processing Record 48 of Set 10 | toungoo
# City not found. Skipping...
# Processing Record 49 of Set 10 | puerto escondido
# Processing Record 50 of Set 10 | sao filipe
# Processing Record 1 of Set 11 | bullhead city
# Processing Record 2 of Set 11 | arcata
# Processing Record 3 of Set 11 | turbat
# Processing Record 4 of Set 11 | hervey bay
# Processing Record 5 of Set 11 | shirpur
# Processing Record 6 of Set 11 | bandarbeyla
# Processing Record 7 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 11 | fare
# Processing Record 9 of Set 11 | emerald
# Processing Record 10 of Set 11 | miri
# Processing Record 11 of Set 11 | issoudun
# Processing Record 12 of Set 11 | anloga
# Processing Record 13 of Set 11 | suao
# City not found. Skipping...
# Processing Record 14 of Set 11 | bardiyah
# Processing Record 15 of Set 11 | les cayes
# Processing Record 16 of Set 11 | dekar
# Processing Record 17 of Set 11 | malaut
# Processing Record 18 of Set 11 | nioro
# Processing Record 19 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 11 | motala
# Processing Record 21 of Set 11 | biak
# Processing Record 22 of Set 11 | keetmanshoop
# Processing Record 23 of Set 11 | shetpe
# Processing Record 24 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 25 of Set 11 | korla
# Processing Record 26 of Set 11 | bermejo
# Processing Record 27 of Set 11 | ankazoabo
# Processing Record 28 of Set 11 | zambezi
# Processing Record 29 of Set 11 | starosubkhangulovo
# Processing Record 30 of Set 11 | puerto narino
# Processing Record 31 of Set 11 | concepcion del oro
# Processing Record 32 of Set 11 | yenagoa
# Processing Record 33 of Set 11 | yarada
# Processing Record 34 of Set 11 | navolato
# Processing Record 35 of Set 11 | chichibu
# Processing Record 36 of Set 11 | volterra
# Processing Record 37 of Set 11 | gizo
# Processing Record 38 of Set 11 | fallon
# Processing Record 39 of Set 11 | carauari
# Processing Record 40 of Set 11 | vanavara
# Processing Record 41 of Set 11 | bolshaya atnya
# City not found. Skipping...
# Processing Record 42 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 11 | arbagar
# Processing Record 44 of Set 11 | kulhudhuffushi
# Processing Record 45 of Set 11 | leningradskiy
# Processing Record 46 of Set 11 | matara
# Processing Record 47 of Set 11 | aktau
# Processing Record 48 of Set 11 | akropong
# Processing Record 49 of Set 11 | yulara
# Processing Record 50 of Set 11 | debre birhan
# Processing Record 1 of Set 12 | myski
# Processing Record 2 of Set 12 | itaueira
# Processing Record 3 of Set 12 | tilichiki
# Processing Record 4 of Set 12 | batemans bay
# Processing Record 5 of Set 12 | walvis bay
# Processing Record 6 of Set 12 | aripuana
# Processing Record 7 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 12 | baykit
# Processing Record 9 of Set 12 | zhuhai
# Processing Record 10 of Set 12 | sinnamary
# Processing Record 11 of Set 12 | acarau
# Processing Record 12 of Set 12 | hundorp
# Processing Record 13 of Set 12 | markova
# Processing Record 14 of Set 12 | baglan
# Processing Record 15 of Set 12 | maragogi
# Processing Record 16 of Set 12 | novikovo
# Processing Record 17 of Set 12 | praya
# Processing Record 18 of Set 12 | iaciara
# Processing Record 19 of Set 12 | ostrovnoy
# Processing Record 20 of Set 12 | longfeng
# Processing Record 21 of Set 12 | yangjiang
# Processing Record 22 of Set 12 | aljezur
# Processing Record 23 of Set 12 | beloha
# Processing Record 24 of Set 12 | treinta y tres
# Processing Record 25 of Set 12 | puerto pinasco
# City not found. Skipping...
# Processing Record 26 of Set 12 | eldorado
# Processing Record 27 of Set 12 | north las vegas
# Processing Record 28 of Set 12 | paamiut
# Processing Record 29 of Set 12 | belmonte
# Processing Record 30 of Set 12 | sisimiut
# Processing Record 31 of Set 12 | zharkent
# Processing Record 32 of Set 12 | tiruvottiyur
# City not found. Skipping...
# Processing Record 33 of Set 12 | huanren
# Processing Record 34 of Set 12 | mugur-aksy
# Processing Record 35 of Set 12 | pecanha
# Processing Record 36 of Set 12 | ishigaki
# Processing Record 37 of Set 12 | san carlos de bariloche
# Processing Record 38 of Set 12 | artvin
# Processing Record 39 of Set 12 | carayao
# Processing Record 40 of Set 12 | wegrow
# Processing Record 41 of Set 12 | vengerovo
# Processing Record 42 of Set 12 | yuli
# Processing Record 43 of Set 12 | pemba
# Processing Record 44 of Set 12 | yinchuan
# Processing Record 45 of Set 12 | jalu
# Processing Record 46 of Set 12 | ponerihouen
# Processing Record 47 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 12 | ugoofaaru
# Processing Record 49 of Set 12 | zhezkazgan
# Processing Record 50 of Set 12 | humberto de campos
# Processing Record 1 of Set 13 | talara
# Processing Record 2 of Set 13 | tocopilla
# Processing Record 3 of Set 13 | warri
# Processing Record 4 of Set 13 | gamboma
# Processing Record 5 of Set 13 | colares
# Processing Record 6 of Set 13 | vila
# Processing Record 7 of Set 13 | yamada
# Processing Record 8 of Set 13 | broken hill
# Processing Record 9 of Set 13 | balikpapan
# Processing Record 10 of Set 13 | canandaigua
# Processing Record 11 of Set 13 | loukhi
# Processing Record 12 of Set 13 | palmeira
# Processing Record 13 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 14 of Set 13 | cabedelo
# Processing Record 15 of Set 13 | sao joao da barra
# Processing Record 16 of Set 13 | los andes
# Processing Record 17 of Set 13 | kashi
# Processing Record 18 of Set 13 | kuytun
# Processing Record 19 of Set 13 | zonguldak
# Processing Record 20 of Set 13 | gat
# Processing Record 21 of Set 13 | sheregesh
# Processing Record 22 of Set 13 | half moon bay
# Processing Record 23 of Set 13 | jalapa
# Processing Record 24 of Set 13 | banmo
# City not found. Skipping...
# Processing Record 25 of Set 13 | campbellton
# Processing Record 26 of Set 13 | finnsnes
# Processing Record 27 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 13 | khvorostyanka
# Processing Record 29 of Set 13 | comodoro rivadavia
# Processing Record 30 of Set 13 | port blair
# Processing Record 31 of Set 13 | shahreza
# Processing Record 32 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 33 of Set 13 | dafeng
# Processing Record 34 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 13 | malakal
# Processing Record 36 of Set 13 | nouadhibou
# Processing Record 37 of Set 13 | zhangye
# Processing Record 38 of Set 13 | lamesa
# Processing Record 39 of Set 13 | dhidhdhoo
# Processing Record 40 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 41 of Set 13 | santiago del estero
# Processing Record 42 of Set 13 | mocuba
# Processing Record 43 of Set 13 | sabang
# Processing Record 44 of Set 13 | herne
# Processing Record 45 of Set 13 | tuy hoa
# Processing Record 46 of Set 13 | shevchenkove
# Processing Record 47 of Set 13 | korcula
# Processing Record 48 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 13 | diego de almagro
# Processing Record 50 of Set 13 | neryungri
# Processing Record 1 of Set 14 | farrukhnagar
# Processing Record 2 of Set 14 | marzuq
# Processing Record 3 of Set 14 | alta floresta
# Processing Record 4 of Set 14 | catamarca
# Processing Record 5 of Set 14 | kabare
# Processing Record 6 of Set 14 | college
# Processing Record 7 of Set 14 | san quintin
# Processing Record 8 of Set 14 | kapoeta
# Processing Record 9 of Set 14 | porto belo
# Processing Record 10 of Set 14 | bushehr
# Processing Record 11 of Set 14 | nuevo progreso
# Processing Record 12 of Set 14 | palauig
# Processing Record 13 of Set 14 | harper
# Processing Record 14 of Set 14 | hingorja
# Processing Record 15 of Set 14 | marmaris
# Processing Record 16 of Set 14 | laviana
# Processing Record 17 of Set 14 | suntar
# Processing Record 18 of Set 14 | fairbanks
# Processing Record 19 of Set 14 | sibu
# Processing Record 20 of Set 14 | talcahuano
# Processing Record 21 of Set 14 | puerto madryn
# Processing Record 22 of Set 14 | key west
# Processing Record 23 of Set 14 | homer
# Processing Record 24 of Set 14 | melioratorov
# Processing Record 25 of Set 14 | avila
# Processing Record 26 of Set 14 | tchamba
# Processing Record 27 of Set 14 | kalagarh
# Processing Record 28 of Set 14 | muros
# Processing Record 29 of Set 14 | den helder
# Processing Record 30 of Set 14 | irbil
# Processing Record 31 of Set 14 | ornes
# Processing Record 32 of Set 14 | turan
# Processing Record 33 of Set 14 | omboue
# Processing Record 34 of Set 14 | oktyabrskiy
# Processing Record 35 of Set 14 | ossora
# Processing Record 36 of Set 14 | tierra blanca
# Processing Record 37 of Set 14 | mazagao
# Processing Record 38 of Set 14 | quang ngai
# Processing Record 39 of Set 14 | cockburn town
# Processing Record 40 of Set 14 | vila franca do campo
# Processing Record 41 of Set 14 | tezu
# Processing Record 42 of Set 14 | vilyuysk
# Processing Record 43 of Set 14 | el alto
# Processing Record 44 of Set 14 | bom jesus da lapa
# Processing Record 45 of Set 14 | koscierzyna
# Processing Record 46 of Set 14 | mount gambier
# Processing Record 47 of Set 14 | maloy
# Processing Record 48 of Set 14 | ogulin
# Processing Record 49 of Set 14 | coihaique
# Processing Record 50 of Set 14 | nizhniy kuranakh
# Processing Record 1 of Set 15 | manono
# Processing Record 2 of Set 15 | turangi
# Processing Record 3 of Set 15 | san ramon
# Processing Record 4 of Set 15 | kemijarvi
# Processing Record 5 of Set 15 | bautar
# Processing Record 6 of Set 15 | garowe
# Processing Record 7 of Set 15 | san cristobal
# Processing Record 8 of Set 15 | tabatinga
# Processing Record 9 of Set 15 | tashtagol
# Processing Record 10 of Set 15 | honiara
# Processing Record 11 of Set 15 | pangnirtung
# Processing Record 12 of Set 15 | belyy yar
# Processing Record 13 of Set 15 | sioux lookout
# Processing Record 14 of Set 15 | vestbygda
# City not found. Skipping...
# Processing Record 15 of Set 15 | gouyave
# Processing Record 16 of Set 15 | lufilufi
# Processing Record 17 of Set 15 | ewo
# Processing Record 18 of Set 15 | hobyo
# Processing Record 19 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 15 | namatanai
# Processing Record 21 of Set 15 | jardim
# Processing Record 22 of Set 15 | skeldon
# Processing Record 23 of Set 15 | mandalgovi
# City not found. Skipping...
# Processing Record 24 of Set 15 | kailasahar
# City not found. Skipping...
# Processing Record 25 of Set 15 | raga
# Processing Record 26 of Set 15 | mogadishu
# Processing Record 27 of Set 15 | jishou
# Processing Record 28 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 15 | chake chake
# Processing Record 30 of Set 15 | roald
# Processing Record 31 of Set 15 | karasjok
# Processing Record 32 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 15 | wajima
# Processing Record 34 of Set 15 | ziro
# Processing Record 35 of Set 15 | tsubata
# Processing Record 36 of Set 15 | prachuap khiri khan
# Processing Record 37 of Set 15 | dakar
# Processing Record 38 of Set 15 | sivakasi
# Processing Record 39 of Set 15 | alihe
# Processing Record 40 of Set 15 | port hawkesbury
# Processing Record 41 of Set 15 | nanortalik
# Processing Record 42 of Set 15 | xichang
# Processing Record 43 of Set 15 | awbari
# Processing Record 44 of Set 15 | nicolas bravo
# Processing Record 45 of Set 15 | cayenne
# Processing Record 46 of Set 15 | deer lake
# Processing Record 47 of Set 15 | phan thiet
# Processing Record 48 of Set 15 | mount pleasant
# Processing Record 49 of Set 15 | lima
# Processing Record 50 of Set 15 | galgani
# City not found. Skipping...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9912\1176429723.py in <module>
#      17         set_count += 1
#      18         record_count = 1
# ---> 19         time.sleep(60)
#      20
#      21     # Create an endpoint URL for each city
#
# KeyboardInterrupt:

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 686

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Khatanga  71.9667  102.5000     12.49        94          41
# 1     Dongsheng  39.8161  109.9776     34.12        34           0
# 2  Puerto Ayora  -0.7393  -90.3518     76.96        85          80
# 3        Bethel  41.3712  -73.4140     66.45        52           0
# 4        Kodiak  57.7900 -152.4072     49.51        81         100
# 5       Ushuaia -54.8000  -68.3000     49.66        40           0
# 6        Faanui -16.4833 -151.7500     78.94        66           8
# 7        Avarua -21.2078 -159.7750     75.25        78          75
# 8     San Pedro  14.3500  121.0167     80.35        90          75
# 9  Saint-Pierre -21.3393   55.4781     69.91        68           0
#
#    Wind Speed Country
# 0        9.33      RU
# 1        7.34      CN
# 2        8.99      EC
# 3        9.22      US
# 4        5.75      US
# 5        4.61      AR
# 6       17.09      PF
# 7        6.91      CK
# 8        8.05      PH
# 9        4.61      RE

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp",
                    "Humidity",  "Cloudiness", "Wind Speed"]

# Recreate the DataFrame by using the new column order
df = city_data_df[new_column_order]

# Display sample data
df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Khatanga      RU  71.9667  102.5000     12.49        94
# 1         Dongsheng      CN  39.8161  109.9776     34.12        34
# 2      Puerto Ayora      EC  -0.7393  -90.3518     76.96        85
# 3            Bethel      US  41.3712  -73.4140     66.45        52
# 4            Kodiak      US  57.7900 -152.4072     49.51        81
# ..              ...     ...      ...       ...       ...       ...
# 681         Cayenne      GF   4.9333  -52.3333     89.64        55
# 682       Deer Lake      CA  49.1667  -57.4316     53.46        94
# 683      Phan Thiet      VN  10.9333  108.1000     77.27        87
# 684  Mount Pleasant      US  32.7941  -79.8626     84.99        41
# 685            Lima      PE -12.0432  -77.0282     74.89        58
#
#      Cloudiness  Wind Speed
# 0            41        9.33
# 1             0        7.34
# 2            80        8.99
# 3             0        9.22
# 4           100        5.75
# ..          ...         ...
# 681          20       10.36
# 682         100        5.75
# 683         100        2.89
# 684           0        5.75
# 685          75       13.80
#
# [686 rows x 8 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9912\3569321987.py in <module>
#       1 # Display the data types of each column by using the dtypes Pandas function
# ----> 2 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# # Set the output file name
# output_data_file = "Weather_Database/WeatherPy_Database.csv"

# # Export the city_data DataFrame into a CSV file
# city_data_df.to_csv(output_data_file)

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
